# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('n1.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (510, 827, 3)

# %%
plt.imshow(img)

# %%
oimg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(oimg)

# %%
imgry = cv2.imread('n1.jpg',cv2.IMREAD_GRAYSCALE)

# %%
imgry
# Out:
# array([[119, 119, 119, ...,  58,  53,  56],
#        [119, 119, 119, ...,  74,  75,  72],
#        [119, 119, 119, ...,  79,  69,  56],
#        ...,
#        [110, 110, 110, ..., 147, 148, 150],
#        [111, 111, 111, ..., 146, 147, 149],
#        [111, 111, 112, ..., 145, 146, 148]], dtype=uint8)

# %%
imgry.max()
# Out:
# 255

# %%
imgry.min()
# Out:
# 0

# %%
plt.imshow(imgry,cmap='gray')

# %%
plt.imshow(oimg)

# %%
oimg.shape
# Out:
# (510, 827, 3)

# %%
nimg = cv2.resize(oimg, (1300,500))

# %%
plt.imshow(nimg)

# %%
wratio = 0.8
hratio = 0.2

# %%
nim = cv2.resize(oimg,(0,0),oimg,wratio,hratio)

# %%
plt.imshow(nim)

# %%
nim.shape
# Out:
# (102, 662, 3)

# %%
nimg = cv2.flip(oimg,0)
plt.imshow(nimg)

# %%
type(oimg)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('newimg.jpg',oimg)
# Out:
# True

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(oimg)
